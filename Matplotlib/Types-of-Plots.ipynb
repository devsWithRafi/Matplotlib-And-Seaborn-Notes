# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns

# %%
x = np.linspace(0, 5, 11)
print(x)

y = x**3
print(y)
# Out:
# [0.  0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5 5. ]
# [  0.      0.125   1.      3.375   8.     15.625  27.     42.875  64.
#   91.125 125.   ]

# %%
plt.scatter(x, y)

# %%
plt.hist(x)
# Out:
# (array([1., 1., 1., 1., 1., 1., 1., 1., 1., 2.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
from random import sample
data = sample(range(1, 1000), 100)
plt.hist(data)
# Out:
# (array([10.,  9., 11., 11.,  8., 11.,  7., 17.,  6., 10.]),
#  array([  3. , 102.2, 201.4, 300.6, 399.8, 499. , 598.2, 697.4, 796.6,
#         895.8, 995. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x258890be850>,
#   <matplotlib.lines.Line2D at 0x258890be990>],
#  'caps': [<matplotlib.lines.Line2D at 0x258890bead0>,
#   <matplotlib.lines.Line2D at 0x258890bec10>],
#  'boxes': [<matplotlib.lines.Line2D at 0x258890be710>],
#  'medians': [<matplotlib.lines.Line2D at 0x258890bed50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x258890bee90>],
#  'means': []}
